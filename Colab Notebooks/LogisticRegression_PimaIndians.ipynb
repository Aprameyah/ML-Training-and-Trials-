# %% [markdown]
# #Coding Assignment 4
# ###*Logistic Regression Program - Pima Indians dataset*
# ###*Author: Sreehari Sreenath*
# Ref: https://www.kaggle.com/uciml/pima-indians-diabetes-database

# %%
# Importing the libraries 
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## load file

# %%
# Importing the dataset
dataset = pd.read_csv('/content/sample_data/pima-indians-diabetes.csv')

# %%
print(dataset.shape)
# Out:
# (768, 9)

# %% [markdown]
# ##Understanding the data

# %%
print(dataset.head())
print(dataset.describe())
print(dataset.info())
# Out:
#    pregnant  plasma_glucose  dia_BP  ...  diab_pedigree  age  Diab
# 0         6             148      72  ...          0.627   50     1
# 1         1              85      66  ...          0.351   31     0
# 2         8             183      64  ...          0.672   32     1
# 3         1              89      66  ...          0.167   21     0
# 4         0             137      40  ...          2.288   33     1
#
# [5 rows x 9 columns]
#          pregnant  plasma_glucose  ...         age        Diab
# count  768.000000      768.000000  ...  768.000000  768.000000
# mean     3.845052      120.894531  ...   33.240885    0.348958
# std      3.369578       31.972618  ...   11.760232    0.476951
# min      0.000000        0.000000  ...   21.000000    0.000000
# 25%      1.000000       99.000000  ...   24.000000    0.000000
# 50%      3.000000      117.000000  ...   29.000000    0.000000
# 75%      6.000000      140.250000  ...   41.000000    1.000000
# ...

# %% [markdown]
# ## Selecting class labels, and featureset

# %%
X = dataset.drop(columns='Diab')
print(X.head(), '\n')

y = dataset['Diab']
print(y.head())
# Out:
#    pregnant  plasma_glucose  dia_BP  ...   bmi  diab_pedigree  age
# 0         6             148      72  ...  33.6          0.627   50
# 1         1              85      66  ...  26.6          0.351   31
# 2         8             183      64  ...  23.3          0.672   32
# 3         1              89      66  ...  28.1          0.167   21
# 4         0             137      40  ...  43.1          2.288   33
#
# [5 rows x 8 columns]
#
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Diab, dtype: int64

# %% [markdown]
# ## Understanding the dataset

# %%
# Visualising the relationship between number of pregnancies and 5-year diabetes risk
plt.scatter(X['pregnant'], y) 
plt.title('pregnancies and 5-year diabetes risk') 
plt.xlabel('pregnancies')
plt.ylabel('diabetes risk')
plt.ylim(-1,2)
plt.show()

#https://stackoverflow.com/questions/47006268/matplotlib-scatter-plot-with-color-label-and-legend-specified-by-c-option

# %%
# Visualising the relationship between bmi and diabetes risk
plt.scatter(X['bmi'], y) 
plt.title('bmi and diabetes risk') 
plt.xlabel('bmi')
plt.ylabel('diabetes risk')
plt.ylim(-1,2)
plt.show()

# %%
# Visualising the relationship between plasma_glucose and diabetes risk
plt.scatter(X['plasma_glucose'], y) 
plt.title('plasma_glucose and diabetes risk') 
plt.xlabel('plasma_glucose')
plt.ylabel('diabetes risk')
plt.ylim(-1,2)
plt.show()

# %% [markdown]
# ###### *fill in the code for identifying the relationship between other variables with the output target of 5-year diabetes risk*

# %%
groups = dataset.groupby("Diab")

# %%
# Visualising the relationship between Diastolic blood pressure and 5-year diabetes risk

for name, group in groups:
    plt.plot(group["dia_BP"], group["Diab"], marker="o", linestyle="", label=name)
plt.title('Diastolic blood pressure and 5-year diabetes risk') 
plt.xlabel('Diastolic blood pressure (mm Hg)')
plt.ylabel('diabetes risk')
plt.ylim(-1,2)
plt.legend()
plt.show()

# %%
# Visualising the relationship between Triceps skin fold thickness and 5-year diabetes risk

for name, group in groups:
    plt.plot(group["skin_thickness"], group["Diab"], marker="o", linestyle="", label=name)
plt.title('Triceps skin fold thickness and 5-year diabetes risk') 
plt.xlabel('Triceps skin fold thickness (mm)')
plt.ylabel('diabetes risk')
plt.ylim(-1,2)
plt.legend()
plt.show()

# %%
# Visualising the relationship between 2-Hour serum insulin and 5-year diabetes risk

for name, group in groups:
    plt.plot(group["serum_insulin"], group["Diab"], marker="o", linestyle="", label=name)
plt.title('2-Hour serum insulin and 5-year diabetes risk') 
plt.xlabel('2-Hour serum insulin (mu U/ml)')
plt.ylabel('diabetes risk')
plt.ylim(-1,2)
plt.legend()
plt.show()

# %%
# Visualising the relationship between Diabetes pedigree function and 5-year diabetes risk

for name, group in groups:
    plt.plot(group["diab_pedigree"], group["Diab"], marker="o", linestyle="", label=name)
plt.title('Diabetes pedigree function and 5-year diabetes risk') 
plt.xlabel('Diabetes pedigree function')
plt.ylabel('diabetes risk')
plt.ylim(-1,2)
plt.legend()
plt.show()

# %%
# Visualising the relationship between Age and 5-year diabetes risk

for name, group in groups:
    plt.plot(group["age"], group["Diab"], marker="o", linestyle="", label=name)
plt.title('Age and 5-year diabetes risk') 
plt.xlabel('Age')
plt.ylabel('diabetes risk')
plt.ylim(-1,2)
plt.legend()
plt.show()

# %% [markdown]
# ###### *Which input variable, do you think, is better in predicting if someone is going to get diabetes in the next 5 year?*

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

#Accuracy when using Pregnancies as input variable
X = dataset.drop([dataset.columns[1], dataset.columns[2],dataset.columns[3], dataset.columns[4],dataset.columns[5], dataset.columns[6],dataset.columns[7], dataset.columns[8]], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
logreg = LogisticRegression(max_iter = 768)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6883116883116883

# %%
#Accuracy when using plasma_glucose as input variable
X = dataset.drop([dataset.columns[0], dataset.columns[2],dataset.columns[3], dataset.columns[4],dataset.columns[5], dataset.columns[6],dataset.columns[7], dataset.columns[8]], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
logreg = LogisticRegression(max_iter = 768)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7445887445887446

# %%
#Accuracy when using BloodPressure as input variable
X = dataset.drop([dataset.columns[0], dataset.columns[1],dataset.columns[3], dataset.columns[4],dataset.columns[5], dataset.columns[6],dataset.columns[7], dataset.columns[8]], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
logreg = LogisticRegression(max_iter = 768)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6796536796536796

# %%
#Accuracy when using SkinThickness as input variable
X = dataset.drop([dataset.columns[0], dataset.columns[1],dataset.columns[2], dataset.columns[4],dataset.columns[5], dataset.columns[6],dataset.columns[7], dataset.columns[8]], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
logreg = LogisticRegression(max_iter = 768)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6796536796536796

# %%
#Accuracy when using Insulin as input variable
X = dataset.drop([dataset.columns[0], dataset.columns[1],dataset.columns[2], dataset.columns[3],dataset.columns[5], dataset.columns[6],dataset.columns[7], dataset.columns[8]], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
logreg = LogisticRegression(max_iter = 768)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6883116883116883

# %%
#Accuracy when using  BMI as input variable
X = dataset.drop([dataset.columns[0], dataset.columns[1],dataset.columns[2], dataset.columns[3],dataset.columns[4], dataset.columns[6],dataset.columns[7], dataset.columns[8]], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
logreg = LogisticRegression(max_iter = 768)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6883116883116883

# %%
#Accuracy when using DiabetesPedigreeFunction as input variable
X = dataset.drop([dataset.columns[0], dataset.columns[1],dataset.columns[2], dataset.columns[3],dataset.columns[4], dataset.columns[5],dataset.columns[7], dataset.columns[8]], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
logreg = LogisticRegression(max_iter = 768)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6926406926406926

# %%
#Accuracy when using age as input variable
X = dataset.drop([dataset.columns[0], dataset.columns[1],dataset.columns[2], dataset.columns[3],dataset.columns[4], dataset.columns[5],dataset.columns[6], dataset.columns[8]], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
logreg = LogisticRegression(max_iter = 768)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6623376623376623

# %% [markdown]
# ###### *write code to find out - how many of the people in the dataset is marked as having 5-year diabetes?*

# %%
# Print number of people who are marked as having 5-year diabetes 
print((dataset['Diab'] == 1).sum())
# Out:
# 268

# %%
#Accuracy when using age, pregnant, bmi as input variables
X = dataset.drop(["plasma_glucose","dia_BP","skin_thickness","serum_insulin","diab_pedigree","Diab"], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
logreg = LogisticRegression(max_iter = 768)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.683982683982684

# %%
confusion_matrix_a = confusion_matrix(y_test, y_pred)
print(confusion_matrix_a)
# Out:
# [[135  22]
#  [ 51  23]]

# %%
#Accuracy when using skin_thickness, diab_pedigree, and dia_BP as input variables
X = dataset.drop(["plasma_glucose","bmi","pregnant","serum_insulin","age","Diab"], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
logreg = LogisticRegression(max_iter = 768)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6796536796536796

# %%
confusion_matrix_b = confusion_matrix(y_test, y_pred)
print(confusion_matrix_b)
# Out:
# [[151   6]
#  [ 68   6]]

# %% [markdown]
# ## Creating Logistic Reg. model and visualizing

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split

X = dataset.drop(columns='Diab')
y = dataset['Diab']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
logreg = LogisticRegression(max_iter = 768)
logreg.fit(X_train, y_train)

# %% [markdown]
# ## Evaluate the performance of our model - Confusion Matrix

# %%
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))

confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
