# %% [markdown]
# # **Author**              : *Sreehari Sreenath*
# # **Program Application** : *Implementation of Codecademy Modules*

# %% [markdown]
# ## **Syntax**

# %% [markdown]
# ### Comments

# %%
# A comment is a piece of text within a program that is not executed. 
# It can be used to provide additional information to aid in understanding the code.
# Example :

UserName = 'Sreehari' #The UserName variable is used to store name.

# %% [markdown]
# ### Arthematic Operation

# %%
a = 10; 
b = 2;

# Python supports different types of arithmetic operations 
# that can be performed on literal numbers, variables, or some combination.

result = a + b  #Addition
result = a - b  #Subtraction
result = a * b  #Multiplication 
result = a / b  #Division
result = a % b  #Modulus (returns the remainder)
result = a ** b #Exponentiation

# %% [markdown]
# ### Plus-Equals Operator +=

# %%
# The plus-equals operator += provides a convenient way to add a value to 
# an existing variable and assign the new value back to the same variable.

a  = 1
print(a)
a += 1
print(a)

a = "Machine"
a += " Learning"
print(a)
# Out:
# 1
# 2
# Machine Learning

# %% [markdown]
# ### Variables

# %%
# A variable is used to store data that will be used by the program. 
# This data can be a number, a string, a Boolean, a list or some other data type. 
# Every variable has a name which can consist of letters, numbers, and the underscore character _.

_string = "HelloWorld !"
print(_string)

integer = 12
print(integer)

Float = 12.04
print(Float)

boolean = True 
print(boolean)

List = ["Machine", "Learning"]
print(List)
# Out:
# HelloWorld !
# 12
# 12.04
# True
# ['Machine', 'Learning']

# %% [markdown]
# ### Modulo Operator %

# %%
# A modulo calculation returns the remainder of a division between the first and second number.
n = 11

if n % 2 == 0:
  print("even")
else:
  print("odd")
# Out:
# odd

# %% [markdown]
# ### Integers

# %%
# An integer is a number that can be written without a fractional part (no decimal). 
# An integer can be a positive number, a negative number or the number 0 so long as there is no decimal portion.

# Example integer numbers
a = 10 
print(type(a))

# Non-integer numbers
a  = 10.0
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ### Strings

# %%
# A string is a sequence of characters (letters, numbers, whitespace or punctuation) enclosed by quotation marks. 
# It can be enclosed using either the double quotation mark " or the single quotation mark '.

# Example 

string = "Machine Learning"
print(type(string))
# Out:
# <class 'str'>

# %% [markdown]
# ### Floating Point Numbers

# %%
# A floating point number is a value that contains a decimal portion. 
# It can be used to represent numbers that have fractional quantities.

# Example 
a  = 10.0
print(type(a))
# Out:
# <class 'float'>

# %% [markdown]
# ### String Concatenation

# %%
# Python supports the joining (concatenation) of strings together using the + operator.

a = "MACHINE "
b = "LEARNING"

print(a+b)
# Out:
# MACHINE LEARNING

# %% [markdown]
# ### print() Function

# %%
# The print() function is used to output text, numbers, or other printable information to the console.

# Example 

print("Printing printing using print")
# Out:
# Printing printing using print

# %% [markdown]
# ### Errors

# %% [markdown]
# #### Syntax Error

# %%
# The Python interpreter will report errors present in your code. 
# For most error cases, the interpreter will display the line of code where the error was detected 
# and place a caret character ^ under the portion of the code where the error was detected.
# Example 

if True == False
  print(10/0)
# Out:
#   File "<ipython-input-57-76491d3a753f>", line 6
#     if True == False
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### ZeroDivisionError

# %%
# A ZeroDivisionError is reported by the Python interpreter when it detects a division operation 
# is being performed and the denominator (bottom number) is 0.

# Example 

if True != False:
  print(10/0)

# %% [markdown]
# #### NameError

# %%
# A NameError is reported by the Python interpreter when it detects a variable that is unknown.

# Example 

print(unknown)

# %% [markdown]
# ## **Functions**

# %% [markdown]
# ### Function Definition

# %%
# The syntax for creating a named function, a function definition, is:
# def name( parameters ):
#    statements

# Example

def hello(name):
    """This function says hello and greets you"""
    print("Hello " + name)
    print("Glad to meet you!")

hello("Dr.Rahul Krishnan")

# %% [markdown]
# ### Function Keyword Arguments

# %%
# Python functions can be defined with named arguments which may have default values provided. 
# When function arguments are passed using their names, they are referred to as keyword arguments. 

#Example

def findvolume(length=1, width=1, depth=1):
   """This function returns volume given the length,width & depth"""
  print("Length = " + str(length))
  print("Width = " + str(width))
  print("Depth = " + str(depth))
  return length * width * depth;

findvolume(1, 2, 3)
findvolume(length=5, depth=2, width=4)
findvolume(2, depth=3, width=4)

# %% [markdown]
# ### Function Indentation

# %%
# Python uses indentation to identify blocks of code.
# A Python function is one type of code block. 
# All code under a function declaration should be indented to identify it as part of the function. 

#Example 
def Testfunction():
   """This function is a trial function to check indentation property"""
   print("Part of the function")
   
print("Not a part of function")
Testfunction()

# %% [markdown]
# ### Multiple Parameter Functions

# %%
# To define a function with multiple parameters, parameter names are placed one after another, 
# separated by commas, within the parentheses of the function definition.

# Example 
def pow(number, power):
  """This function returns an integer = number^power"""
  return number ** power

pow(2, 10)

# %% [markdown]
# ### Returning Multiple Values

# %%
# Python functions are able to return multiple values using one return statement. 
# All values that should be returned are listed after the return keyword and are separated by commas.

#Example 
def square_point(x, y, z):
   """This function returns the sqaure of x,y & z"""
  x_squared = x * x
  y_squared = y * y
  z_squared = z * z
  # Return all three values:
  return x_squared, y_squared, z_squared

three_squared, four_squared, five_squared = square_point(3, 4, 5)
print(three_squared)
print(four_squared)
print(five_squared)

# %% [markdown]
# ### The Scope of Variables

# %%
# GLOBAL variable : A variable that is defined outside of a function is called a global variable. 
# It can be accessed inside the body of a function.

# LOCAL variable :  a variable defined inside a function is called a local variable. 
# It cannot be used outside of the scope of the function

a = 10 #global variable

def testscope():
     """This function is to test a scope of variable"""
     a = 5 #local variable
     print(a)

print(a)
testscope()

# %% [markdown]
# ## **Control Flow**

# %% [markdown]
# ### Boolean Values & Expressions

# %%
# Booleans are a data type in Python & have two values:
# True
# False

is_true = True
is_false = False
print(type(is_true)) 

#A boolean expression is an expression that evaluates to a boolean value.
#Example

print(5 == 5)
print(5 == 6)
# Out:
# <class 'bool'>
# True
# False

# %% [markdown]
# ### Relational Operators

# %%
# These operators compare the values on either sides of them and decide the relation among them. 
# They are also called  Comparison Operators.

# ==	operator  : If the values of two operands are equal, then the condition becomes true.
# !=  operator  : If values of two operands are not equal, then condition becomes true.
# >	  operator  : If the value of left operand is greater than the value of right operand, then condition becomes true.
# <	  operator  : If the value of left operand is less than the value of right operand, then condition becomes true.
# >=	operator  : If the value of left operand is greater than or equal to the value of right operand, then condition becomes true.
#	<=	operator  : If the value of left operand is less than or equal to the value of right operand, then condition becomes true.

#Examples 

print(5 == 6)
print(5 != 6)
print(5 > 6)
print(5 < 6)
print(5 >= 6)
print(5 <= 6)

# %% [markdown]
# ### Logical operators

# %%
# There are three logical operators: and, or, and not. 
# The semantics of these operators is similar to their meaning in English.

#Examples
a = 5 
b = 6

# "and" operator
# The Python and operator performs a Boolean comparison between two Boolean values, variables, or expressions. 
# If both sides of the operator evaluate to True then the and operator returns True. 
# If either side (or both sides) evaluates to False, then the and operator returns False. 

print(a <= b  and a < b)

# "or" operator
# The Python or operator combines two Boolean expressions and evaluates to True if at least one of the expressions returns True. 
# Otherwise, if both expressions are False, then the entire expression evaluates to False.

print(a == 5 or a >= b)

# "not" operator 
# The Python Boolean not operator is used in a Boolean expression in order to evaluate the expression to its inverse value.

print(not False)

# %% [markdown]
# ### If Statement

# %%
# The Python if statement is used to determine the execution of code based on the evaluation of a Boolean expression.
# If the if statement expression evaluates to True, then the indented code following the statement is executed.
# If the expression evaluates to False then the indented code following the if statement is skipped 
# and the program executes the next line of code which is indented at the same level as the if statement.

#Example 

number  = 15
if number  % 2 == 0:
    print(number, "is even")

# %% [markdown]
# ### Else Statement

# %%
# The Python else statement provides alternate code to execute if the expression in an if statement evaluates to False.

#Example

number  = 15
if number  % 2 == 0:
    print(number, "is even")
else:
    print(number, "is odd")

# %% [markdown]
# ### Elif Statment

# %%
# The Python elif statement allows for continued checks to be performed after an initial if statement. 
# An elif statement differs from the else statement because another expression is provided to be checked, 
# just as with the initial if statement.

pet_type = "lion"

if pet_type == "dog":
  print("You have a dog.")
elif pet_type == "cat":
  print("You have a cat.")
elif pet_type == "lion":
  # this is performed
  print("You have a lion")
else:
  print("Not sure!")
# Out:
# You have a lion

# %% [markdown]
# ## **List**

# %% [markdown]
# ### List Properties

# %%
# Lists are ordered collections of items that allow for easy use of a set of data.
# List values are placed in between square brackets [ ], separated by commas.
# Empty lists do not contain any values within the square brackets.
# In Python, lists are a versatile data type that can contain multiple different data types within the same square brackets. 
# The possible data types within a list include numbers, strings, other objects, and even other lists.
# Python list elements are ordered by index, a number referring to their placement in the list. 
# List indices start at 0 and increment by one.
# To access a list element by index, square bracket notation is used: list[index].
# Negative indices for lists can also be used to reference elements in relation to the end of a list.
# A slice, or sub-list of Python list elements can be selected from a list using a colon-separated starting and ending point.

# Examples
empty_List = []
print(type(empty_List))
List = ["Alpha", "Bravo", "Charlie", "Delta", 1, 2, 3, 4]
print(List)
print(List[0])
NatoList = List[0:4]
print(NatoList)
NumericList = List[-4:]
NumericList[0] = 0 
print(NumericList)

# %% [markdown]
# ### List Methods

# %%
# append()  : You can add values to the end of a list using the .append() method.
# zip()     : The data types that can be iterated (called iterables) can be used with the zip() function to aggregate data. 
#             The zip() function takes iterables, aggregates corresponding elements based on the iterables passed in, 
#             and returns an iterator.Each element of the returned iterator is a tuple of values.
# count()   : It searches a list for whatever search term it receives as an argument, then returns the number of matching entries found
# len()     : The len() function can be used to determine the number of items found in the list it accepts as an argument.
# sort()    : will sort the contents of whatever list it is called on. 
#             Numerical lists will be sorted in ascending order, and lists of Strings will be sorted into alphabetical order.
#             It modifies the original list, and has no return value
# sorted()  : Similar to sort, but It does not modify the original, unsorted list.



#Examples :
NatoList = ["Alpha", "Bravo", "Charlie", "Delta"]
NumericList = [1, 2, 3, 4, 5]

NatoList.append("Echo")
print(NatoList)

List = zip(NatoList, NumericList)
print(list(List))

NumOnes = NumericList.count(2)
print(NumOnes)

print(len(NatoList))

NatoList.sort()
NewNatoList = sorted(NatoList)
print(NewNatoList)
# Out:
# ['Alpha', 'Bravo', 'Charlie', 'Delta', 'Echo']
# [('Alpha', 1), ('Bravo', 2), ('Charlie', 3), ('Delta', 4), ('Echo', 5)]
# 1
# 5
# ['Alpha', 'Bravo', 'Charlie', 'Delta', 'Echo']

# %% [markdown]
# ##**Loops**

# %% [markdown]
# ### 'For' Loop

# %%
# Python for loops can be used to iterate over and perform an action one time for each element in a list.
# Example 

dog_breeds = ["boxer", "bulldog", "shiba inu"]

# Print each breed:
for breed in dog_breeds:
  print(breed)

# %% [markdown]
# ### Nested 'for' loop

# %%
# In Python, loops can be nested inside other loops. 
# Nested loops can be used to access items of lists which are inside other lists.
# Example

groups = [["Jobs", "Gates"], ["Newton", "Euclid"], ["Einstein", "Feynman"]]

# This outer loop will iterate over each list in the groups list
for group in groups:
  # This inner loop will go through each name in each list
  for name in group:
    print(name)

# %% [markdown]
# ### 'For' loop with range() function

# %%
# The range() function can be used to create a list that can be used to specify the number of iterations in a for loop.
# Example : 

# Print the numbers 0, 1, 2:
for i in range(3):
  print(i)

# Print "WARNING" 3 times:
for i in range(3):
  print("WARNING")

# %% [markdown]
# ### 'While' loop

# %%
# a while loop will repeatedly execute a code block as long as a condition evaluates to True.
# The condition of a while loop is always checked first before the block of code runs. 
# If the condition is not met initially, then the code block will never run.
# Example

# This loop will only run 1 time
hungry = True
while hungry:
  print("Time to eat!")
  hungry = False

# This loop will run 5 times
i = 1
while i < 6:
  print(i)
  i = i + 1

# %% [markdown]
# ### 'Continue' and 'break' keyword

# %%
# Break
# In a loop, the break keyword escapes the loop, regardless of the iteration number. 
# Once break executes, the program will continue to execute after the loop.
# Example 

numbers = [0, 254, 2, -1, 3]

for num in numbers:
  if (num < 0):
    print("Negative number detected!")
    break
  print(num)

# Continue
# The continue keyword is used inside a loop to skip the remaining code inside the loop code block and begin the next loop iteration.
# Example

big_number_list = [1, 2, -1, 4, -5, 5, 2, -9]

# Print only positive numbers:
for i in big_number_list:
  if i < 0:
    continue
  print(i)

# %% [markdown]
# ## **Strings**

# %% [markdown]
# ###Escaping Characters

# %%
# Backslashes (\) are used to escape characters in a Python string.
# Example

txt = "She said \"Never let go\"."
print(txt) # She said "Never let go".

# %% [markdown]
# ### 'in' syntax

# %%
# The in syntax is used to determine if a letter or a substring exists in a string. 
# It returns True if a match is found, otherwise False is returned.
# Example

game = "Popular Nintendo Game: Mario Kart"

print("l" in game) # Prints: True
print("x" in game) # Prints: False

# %% [markdown]
# ### Indexing and Slicing Strings

# %%
# Python strings can be indexed using the same notation as lists, since strings are lists of characters. 
# A single character can be accessed with bracket notation ([index]), or a substring can be accessed using slicing ([start:end]).
# Indexing with negative numbers counts from the end of the string.
# Example

str = 'yellow'
print(str[1])     # => 'e'
print(str[-1])    # => 'w'
print(str[4:6])   # => 'ow'
print(str[:4])    # => 'yell'
print(str[-3:])   # => 'low'

# %% [markdown]
# ### Iterate String

# %%
# To iterate through a string in Python, “for…in” notation is used.
# Example
 
str = "hello" 
for c in str:
  print(c)

# %% [markdown]
# ### len() function for string

# %%
# the built-in len() function can be used to determine the length of an object. 
# It can be used to compute the length of strings, lists, sets, and other countable objects.
# Example 

length = len("Hello")
print(length)
# Output: 5

colors = ['red', 'yellow', 'green']
print(len(colors))
# Output: 3

# %% [markdown]
# ### String Methods

# %%
# format()  : The Python string method .format() replaces empty brace ({}) placeholders in the string with its arguments.
# lower()   : The string method .lower() returns a string with all uppercase characters converted into lowercase.
# strip()   : The string method .strip() can be used to remove characters from the beginning and end of a string.
# title()   : The string method .title() returns the string in title case.
# split()   : The string method .split() splits a string into a list of items:
#               If no argument is passed, the default behavior is to split on whitespace.
#               If an argument is passed to the method, that value is used as the delimiter on which to split the string.
# find()    : The Python string method .find() returns the index of the first occurrence of the string passed as the argument. 
#             It returns -1 if no occurrence is found.
# upper()   : The string method .upper() returns the string with all lowercase characters converted to uppercase.
# join()    : The string method .join() concatenates a list of strings together to create a new string joined with the desired delimiter.
#             The .join() method is run on the delimiter and the array of strings to be concatenated together is passed in as an argument
# Examples

msg2 = 'Fred {verb} a {adjective} {noun}.'
msg2.format(adjective='fluffy', verb='tickled', noun='hamster')
# => 'Fred tickled a fluffy hamster.'

greeting = "Welcome To Chili's"
print(greeting.lower())
# Prints: welcome to chili's

text1 = '   apples and oranges   '
text1.strip()       # => 'apples and oranges'

my_var = "dark knight"
print(my_var.title()) 
# Prints: Dark Knight

text = "Silicon Valley"
print(text.split())     
# Prints: ['Silicon', 'Valley']
print(text.split('i'))  
# Prints: ['S', 'l', 'con Valley']

mountain_name = "Mount Kilimanjaro"
print(mountain_name.find("o")) # Prints 1 in the console.

dinosaur = "T-Rex"
print(dinosaur.upper()) 
# Prints: T-REX

x = "-".join(["Codecademy", "is", "awesome"])
print(x) 
# Prints: Codecademy-is-awesome
